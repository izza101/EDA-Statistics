# %% [markdown]
# #### Task 1 : Define Library

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# #### Task 2 : Read Data (CSV)

# %%
df = pd.read_csv('data_by_year.csv')

# %% [markdown]
# #### Task 3 : Head and Tail Data

# %%
df.head()
# Out:
#    year  acousticness  danceability    duration_ms    energy  \
# 0  1921      0.895823      0.425661  229911.914062  0.236784
# 1  1922      0.939236      0.480000  167904.541667  0.237026
# 2  1923      0.976329      0.568462  178356.301775  0.246936
# 3  1924      0.935575      0.548654  188461.649789  0.347033
# 4  1925      0.965422      0.571890  184130.699620  0.264373
#
#    instrumentalness  liveness   loudness  speechiness       tempo   valence  \
# 0          0.322330  0.215814 -17.095437     0.077258  100.397758  0.425495
# 1          0.440470  0.238647 -19.179958     0.115419  101.376139  0.534056
# 2          0.401932  0.236656 -14.373882     0.098619  112.456598  0.624788
# 3          0.583955  0.237875 -14.202304     0.090210  120.653359  0.668574
# 4          0.408893  0.243094 -14.516707     0.115457  115.671715  0.616430
#
#    popularity  key  mode
# 0    0.351562    7     1
# 1    0.138889   10     1
# 2    5.727811    0     1
# 3    0.603376   10     1
# ...

# %%
df.tail()
# Out:
#     year  acousticness  danceability    duration_ms    energy  \
# 95  2016      0.280290      0.599976  219400.763840  0.592877
# 96  2017      0.289916      0.612286  209343.613000  0.586739
# 97  2018      0.271941      0.664930  200919.119000  0.590591
# 98  2019      0.289298      0.644215  197733.133000  0.578796
# 99  2020      0.247374      0.673077  197114.662301  0.611914
#
#     instrumentalness  liveness  loudness  speechiness       tempo   valence  \
# 95          0.074646  0.180198 -7.949913     0.107298  119.070344  0.430769
# 96          0.098209  0.194218 -8.422697     0.111752  116.840278  0.414465
# 97          0.035948  0.171781 -7.253666     0.128140  122.004325  0.447141
# 98          0.076518  0.167161 -8.041738     0.124799  118.868163  0.465856
# 99          0.039052  0.177048 -7.204024     0.143505  121.228704  0.482755
#
#     popularity  key  mode
# 95   61.371254    0     1
# 96   64.861500    1     1
# 97   67.276000    1     1
# ...

# %% [markdown]
# #### Task 4 : Total Number of Rows and Columns

# %%
df.shape
# Out:
# (100, 14)

# %% [markdown]
# #### Task 5 : Columns Name and Index

# %%
df.columns
# Out:
# Index(['year', 'acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo',
#        'valence', 'popularity', 'key', 'mode'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %% [markdown]
# #### Task 6 : Missing Value

# %%
df.isna().sum()
# Out:
# year                0
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# liveness            0
# loudness            0
# speechiness         0
# tempo               0
# valence             0
# popularity          0
# key                 0
# mode                0
# dtype: int64

# %% [markdown]
# #### Task 7 : Data Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   year              100 non-null    int64
#  1   acousticness      100 non-null    float64
#  2   danceability      100 non-null    float64
#  3   duration_ms       100 non-null    float64
#  4   energy            100 non-null    float64
#  5   instrumentalness  100 non-null    float64
#  6   liveness          100 non-null    float64
#  7   loudness          100 non-null    float64
#  8   speechiness       100 non-null    float64
#  9   tempo             100 non-null    float64
#  10  valence           100 non-null    float64
#  11  popularity        100 non-null    float64
#  12  key               100 non-null    int64
#  13  mode              100 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 11.1 KB

# %% [markdown]
# #### Task 8 : Descriptive Statistics
# ###### 1. Measures of Central tendency
#     a. mean
#     b. median
#     c. mode

# %%
df.mean()
# Out:
# year                  1970.500000
# acousticness             0.552625
# danceability             0.537485
# duration_ms         226930.361382
# energy                   0.455864
# instrumentalness         0.192160
# liveness                 0.209335
# loudness               -11.916648
# speechiness              0.101247
# tempo                  116.026461
# valence                  0.536384
# popularity              27.223173
# key                      4.190000
# mode                     1.000000
# dtype: float64

# %%
df.median()
# Out:
# year                  1970.500000
# acousticness             0.452951
# danceability             0.544746
# duration_ms         234673.799962
# energy                   0.498728
# instrumentalness         0.124916
# liveness                 0.207946
# loudness               -11.761679
# speechiness              0.086237
# tempo                  117.597018
# valence                  0.548000
# popularity              33.655500
# key                      5.000000
# mode                     1.000000
# dtype: float64

# %%
df.mode()
# Out:
#     year  acousticness  danceability    duration_ms    energy  \
# 0   1921      0.228712      0.403515  167904.541667  0.204252
# 1   1922      0.236197      0.425661  169983.425325  0.207143
# 2   1923      0.237614      0.436234  170391.501144  0.227028
# 3   1924      0.239382      0.439915  178356.301775  0.236784
# 4   1925      0.241118      0.441623  179379.573460  0.237026
# ..   ...           ...           ...            ...       ...
# 95  2016      0.940088      0.644215  258175.421000  0.671269
# 96  2017      0.943474      0.647005  259626.214500  0.673011
# 97  2018      0.946188      0.649960  261744.599500  0.675861
# 98  2019      0.965422      0.664930  262658.912841  0.680766
# 99  2020      0.976329      0.673077  266387.733000  0.693696
#
#     instrumentalness  liveness   loudness  speechiness       tempo   valence  \
# 0           0.035948  0.167161 -19.179958     0.051050  100.397758  0.373623
# ...

# %% [markdown]
# #### Task 8 : Descriptive Statistics
# ###### 1. Measures of spread
#     a. Range
#     b. Quartile and Interquartile Range
#     c. Variance
#     d. Standart Deviation

# %%
Range = df.max()-df.min()
Range
# Out:
# year                   99.000000
# acousticness            0.747617
# danceability            0.269563
# duration_ms         98483.191333
# energy                  0.489444
# instrumentalness        0.548007
# liveness                0.097187
# loudness               12.485687
# speechiness             0.434228
# tempo                  23.259060
# valence                 0.294951
# popularity             69.516611
# key                    10.000000
# mode                    0.000000
# dtype: float64

# %%
df.quantile([0.25,0.5,0.75])
# Out:
#          year  acousticness  danceability    duration_ms    energy  \
# 0.25  1945.75      0.282738      0.500161  208882.913176  0.286154
# 0.50  1970.50      0.452951      0.544746  234673.799962  0.498728
# 0.75  1995.25      0.867022      0.571744  248234.122455  0.600955
#
#       instrumentalness  liveness   loudness  speechiness       tempo  \
# 0.25          0.098798  0.198728 -14.309401     0.065124  111.802986
# 0.50          0.124916  0.207946 -11.761679     0.086237  117.597018
# 0.75          0.277763  0.220389  -9.715595     0.104962  120.819829
#
#        valence  popularity  key  mode
# 0.25  0.495800    2.939625  0.0   1.0
# 0.50  0.548000   33.655500  5.0   1.0
# 0.75  0.574516   44.411125  7.0   1.0

# %%
df.var()
# Out:
# year                8.416667e+02
# acousticness        7.958764e-02
# danceability        2.707409e-03
# duration_ms         6.386024e+08
# energy              2.709956e-02
# instrumentalness    1.680197e-02
# liveness            3.326025e-04
# loudness            9.808809e+00
# speechiness         4.356401e-03
# tempo               3.311003e+01
# valence             3.409859e-03
# popularity          4.411583e+02
# key                 1.286253e+01
# mode                0.000000e+00
# dtype: float64

# %%
df.std()
# Out:
# year                   29.011492
# acousticness            0.282113
# danceability            0.052033
# duration_ms         25270.584548
# energy                  0.164619
# instrumentalness        0.129622
# liveness                0.018237
# loudness                3.131902
# speechiness             0.066003
# tempo                   5.754132
# valence                 0.058394
# popularity             21.003768
# key                     3.586436
# mode                    0.000000
# dtype: float64

# %% [markdown]
# Using Describe ()

# %%
df.describe()
# Out:
#               year  acousticness  danceability    duration_ms      energy  \
# count   100.000000    100.000000    100.000000     100.000000  100.000000
# mean   1970.500000      0.552625      0.537485  226930.361382    0.455864
# std      29.011492      0.282113      0.052033   25270.584548    0.164619
# min    1921.000000      0.228712      0.403515  167904.541667    0.204252
# 25%    1945.750000      0.282738      0.500161  208882.913176    0.286154
# 50%    1970.500000      0.452951      0.544746  234673.799962    0.498728
# 75%    1995.250000      0.867022      0.571744  248234.122455    0.600955
# max    2020.000000      0.976329      0.673077  266387.733000    0.693696
#
#        instrumentalness    liveness    loudness  speechiness       tempo  \
# count        100.000000  100.000000  100.000000   100.000000  100.000000
# mean           0.192160    0.209335  -11.916648     0.101247  116.026461
# std            0.129622    0.018237    3.131902     0.066003    5.754132
# ...

# %%
sns.boxplot(df['tempo'], color = 'green')
plt.show()

# %%
l = df.columns.values
number_of_columns=14
number_of_rows = len(l)-1/number_of_columns
plt.figure(figsize=(number_of_columns,5*number_of_rows))
for i in range(0,len(l)):
    plt.subplot(number_of_rows + 1,number_of_columns,i+1)
    sns.set_style('whitegrid')
    sns.boxplot(df[l[i]],color='green',orient='v')
    plt.tight_layout()

# %%
sns.boxplot(df['instrumentalness'], color = 'green')
plt.show()

# %%
df['instrumentalness'].sort_values(ascending = False)
# Out:
# 3     0.583955
# 7     0.516979
# 25    0.495375
# 5     0.468505
# 20    0.448218
#         ...
# 87    0.061076
# 93    0.058543
# 94    0.058262
# 99    0.039052
# 97    0.035948
# Name: instrumentalness, Length: 100, dtype: float64

# %%
df.hist('instrumentalness', color = 'green')
plt.show()

# %%
df.hist(figsize=(16, 15), xlabelsize=8, ylabelsize=8, color = "green")
plt.show()

# %% [markdown]
# #### Task 8 : Descriptive Statistics
# ###### 1. Measures to Describe Shape of Distribution
#     a. Skewness
#     b. Kurtosis

# %%
skew = df.skew().to_frame()
skew
# Out:
#                          0
# year              0.000000
# acousticness      0.228083
# danceability      0.032675
# duration_ms      -0.567899
# energy           -0.125503
# instrumentalness  1.028267
# liveness          0.229717
# loudness          0.066280
# speechiness       3.446855
# tempo            -0.674085
# valence          -0.399485
# popularity        0.043466
# key              -0.017320
# mode              0.000000

# %%
kurtosis = df.kurtosis().to_frame()
kurtosis
# Out:
#                           0
# year              -1.200000
# acousticness      -1.745978
# danceability       0.136101
# duration_ms       -0.772094
# energy            -1.691329
# instrumentalness   0.050488
# liveness           0.211713
# loudness          -0.889842
# speechiness       14.272313
# tempo             -0.487244
# valence           -0.080470
# popularity        -1.326863
# key               -1.656646
# mode               0.000000

# %%
skew['1'] = kurtosis

# %%
skew.columns = ['skewness','kurtosis']

# %%
skew
# Out:
#                   skewness   kurtosis
# year              0.000000  -1.200000
# acousticness      0.228083  -1.745978
# danceability      0.032675   0.136101
# duration_ms      -0.567899  -0.772094
# energy           -0.125503  -1.691329
# instrumentalness  1.028267   0.050488
# liveness          0.229717   0.211713
# loudness          0.066280  -0.889842
# speechiness       3.446855  14.272313
# tempo            -0.674085  -0.487244
# valence          -0.399485  -0.080470
# popularity        0.043466  -1.326863
# key              -0.017320  -1.656646
# mode              0.000000   0.000000

# %%
sns.distplot(df['speechiness'])
plt.show()

# %%
plt.figure(figsize=(2*number_of_columns,5*number_of_rows))
for i in range(0,len(l)):
    plt.subplot(number_of_rows + 1,number_of_columns,i+1)
    sns.distplot(df[l[i]],kde=True)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# #### Task 9 : Correlation

# %%
k = 14 #number of variables for heatmap
cols = df.corr().nlargest(k, 'year')['year'].index
cm = df[cols].corr()
plt.figure(figsize=(15,10))
sns.heatmap(cm, annot=True, cmap = 'viridis')
plt.show()

# %%
cols
# Out:
# Index(['year', 'popularity', 'energy', 'loudness', 'tempo', 'danceability',
#        'duration_ms', 'key', 'valence', 'speechiness', 'liveness',
#        'instrumentalness', 'acousticness'],
#       dtype='object')

# %%
plt.figure(figsize=(15, 10))

sns.heatmap(cm[(cm >= 0.7) | (cm <= -0.5)], 
            cmap='viridis', vmax=1.0, vmin=-1.0, linewidths=0.1,
            annot=True, square=True);

# %%
plt.figure(figsize = (12,8))
sns.scatterplot(y = df['popularity'], x = df['year'])
plt.show()

# %%
plt.figure(figsize = (12,8))
sns.scatterplot(y = df['acousticness'], x = df['energy'])
plt.show()

# %%
for i in range(0, len(df.columns), 5):
    sns.pairplot(data=df,
                x_vars=df.columns[i:i+5],
                y_vars=['year'])

# %%
df.duration_ms
# Out:
# 0     229911.914062
# 1     167904.541667
# 2     178356.301775
# 3     188461.649789
# 4     184130.699620
#           ...
# 95    219400.763840
# 96    209343.613000
# 97    200919.119000
# 98    197733.133000
# 99    197114.662301
# Name: duration_ms, Length: 100, dtype: float64

# %%
df.loudness
# Out:
# 0    -17.095437
# 1    -19.179958
# 2    -14.373882
# 3    -14.202304
# 4    -14.516707
#         ...
# 95    -7.949913
# 96    -8.422697
# 97    -7.253666
# 98    -8.041738
# 99    -7.204024
# Name: loudness, Length: 100, dtype: float64

# %%
df.mode()
# Out:
#     year  acousticness  danceability    duration_ms    energy  \
# 0   1921      0.228712      0.403515  167904.541667  0.204252
# 1   1922      0.236197      0.425661  169983.425325  0.207143
# 2   1923      0.237614      0.436234  170391.501144  0.227028
# 3   1924      0.239382      0.439915  178356.301775  0.236784
# 4   1925      0.241118      0.441623  179379.573460  0.237026
# ..   ...           ...           ...            ...       ...
# 95  2016      0.940088      0.644215  258175.421000  0.671269
# 96  2017      0.943474      0.647005  259626.214500  0.673011
# 97  2018      0.946188      0.649960  261744.599500  0.675861
# 98  2019      0.965422      0.664930  262658.912841  0.680766
# 99  2020      0.976329      0.673077  266387.733000  0.693696
#
#     instrumentalness  liveness   loudness  speechiness       tempo   valence  \
# 0           0.035948  0.167161 -19.179958     0.051050  100.397758  0.373623
# ...

# %%
df.head()
# Out:
#    year  acousticness  danceability    duration_ms    energy  \
# 0  1921      0.895823      0.425661  229911.914062  0.236784
# 1  1922      0.939236      0.480000  167904.541667  0.237026
# 2  1923      0.976329      0.568462  178356.301775  0.246936
# 3  1924      0.935575      0.548654  188461.649789  0.347033
# 4  1925      0.965422      0.571890  184130.699620  0.264373
#
#    instrumentalness  liveness   loudness  speechiness       tempo   valence  \
# 0          0.322330  0.215814 -17.095437     0.077258  100.397758  0.425495
# 1          0.440470  0.238647 -19.179958     0.115419  101.376139  0.534056
# 2          0.401932  0.236656 -14.373882     0.098619  112.456598  0.624788
# 3          0.583955  0.237875 -14.202304     0.090210  120.653359  0.668574
# 4          0.408893  0.243094 -14.516707     0.115457  115.671715  0.616430
#
#    popularity  key  mode
# 0    0.351562    7     1
# 1    0.138889   10     1
# 2    5.727811    0     1
# 3    0.603376   10     1
# ...

# %%
df.groupby('year')[['acousticness', 'danceability', 'duration_ms', 'energy',
       'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo',
       'valence', 'popularity', 'key', 'mode']].sum()
# Out:
#       acousticness  danceability    duration_ms    energy  instrumentalness  \
# year
# 1921      0.895823      0.425661  229911.914062  0.236784          0.322330
# 1922      0.939236      0.480000  167904.541667  0.237026          0.440470
# 1923      0.976329      0.568462  178356.301775  0.246936          0.401932
# 1924      0.935575      0.548654  188461.649789  0.347033          0.583955
# 1925      0.965422      0.571890  184130.699620  0.264373          0.408893
# ...            ...           ...            ...       ...               ...
# 2016      0.280290      0.599976  219400.763840  0.592877          0.074646
# 2017      0.289916      0.612286  209343.613000  0.586739          0.098209
# 2018      0.271941      0.664930  200919.119000  0.590591          0.035948
# 2019      0.289298      0.644215  197733.133000  0.578796          0.076518
# 2020      0.247374      0.673077  197114.662301  0.611914          0.039052
#
# ...

# %%
df['mode'].nunique()
# Out:
# 1

# %%
df.corr()
# Out:
#                       year  acousticness  danceability  duration_ms    energy  \
# year              1.000000     -0.922472      0.536385     0.536314  0.929389
# acousticness     -0.922472      1.000000     -0.592065    -0.598229 -0.971622
# danceability      0.536385     -0.592065      1.000000    -0.024408  0.577360
# duration_ms       0.536314     -0.598229     -0.024408     1.000000  0.600383
# energy            0.929389     -0.971622      0.577360     0.600383  1.000000
# instrumentalness -0.853655      0.869827     -0.490333    -0.484800 -0.851709
# liveness         -0.616820      0.494254     -0.410532    -0.213847 -0.477962
# loudness          0.923169     -0.874271      0.656247     0.448097  0.933734
# speechiness      -0.353955      0.274185      0.204205    -0.459290 -0.403722
# tempo             0.778410     -0.854827      0.633426     0.478158  0.897127
# valence          -0.217423     -0.043512      0.289993    -0.046297  0.085447
# ...
